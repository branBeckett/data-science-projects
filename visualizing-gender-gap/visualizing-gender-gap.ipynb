# %% [markdown]
# # Visualizing The Gender Gap In College Degrees
#
# ## Introduction
#
# In this project we are going to use data containing the percentage of bachelor's degrees granted to women from 1970 to 2012 to visualize the gender gap across college degrees in the US. We will then clean up the plots to more effectively and cleanly visualize the data.
#
# The data originally comes from the Department of Education Statistics, and our dataset has been cleaned and made available by Randal Olson on his personal website [here](http://www.randalolson.com/wp-content/uploads/percent-bachelors-degrees-women-usa.csv).
#
# First we will import the necessary libraries and plot out some simple visualizations of the gender gap for 6 of the STEM degrees.

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']

fig = plt.figure(figsize=(18, 3))

for sp in range(0,6):
    ax = fig.add_subplot(1,6,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines['right'].set_visible(False)    
    ax.spines['left'].set_visible(False)
    ax.spines['top'].set_visible(False)    
    ax.spines['bottom'].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom='off', top='off', left='off', right='off')
    
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        
plt.show()

# %% [markdown]
# ## Comparing Across All Degrees
#
# We are going to plot the gender gap for all 17 of the degrees in our dataset, but sorted into columns by STEM, Liberal Arts, and Other categories.

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

# %%
fig = plt.figure(figsize=(16,20))

## First column of line charts for STEM degrees.
for sp in range(0,18,3):
    cat_index = int(sp/3) # this is so we line up the plots for each category in the 1st, 2nd, and 3rd columns 0 3 6 9 12 15
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[cat_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[cat_index]], c=cb_orange, label='Men', linewidth=3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[cat_index])
    ax.tick_params(bottom='off', top='off', left='off', right='off')
    
    if cat_index == 0:
        ax.text(2005, 10, 'Men')
        ax.text(2003, 85, 'Women')
    elif cat_index == 5:
        ax.text(2003, 87, 'Men')
        ax.text(2005, 7, 'Women')

## Second column of line charts for Liberal Arts degrees.
for sp in range(1,16,3):
    cat_index = int((sp-1)/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[cat_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[cat_index]], c=cb_orange, label='Men', linewidth=3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[cat_index])
    ax.tick_params(bottom='off', top='off', left='off', right='off')
    
    if cat_index == 0:
        ax.text(2005, 18, 'Men')
        ax.text(2003, 78, 'Women')

## Third column of line charts for Other degrees.
for sp in range(2,20,3):
    cat_index = int((sp-2)/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[cat_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[cat_index]], c=cb_orange, label='Men', linewidth=3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[cat_index])
    ax.tick_params(bottom='off', top='off', left='off', right='off')
    
    if cat_index == 0:
        ax.text(2005, 5, 'Men')
        ax.text(2003, 90, 'Women')
    elif cat_index == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2003, 30, 'Women')

plt.show()

# %% [markdown]
# ## Hiding x-axis Labels
#
# We want to hide the x-axis labels on most of our plots for a cleaner visualization.

# %%
fig = plt.figure(figsize=(16,20))

## First column of line charts for STEM degrees.
for sp in range(0,18,3):
    cat_index = int(sp/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[cat_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[cat_index]], c=cb_orange, label='Men', linewidth=3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[cat_index])
    ax.tick_params(bottom='off', top='off', left='off', right='off', labelbottom='off') # added labelbottom='off'
    
    if cat_index == 0:
        ax.text(2005, 10, 'Men')
        ax.text(2003, 85, 'Women')
    elif cat_index == 5:
        ax.text(2003, 87, 'Men')
        ax.text(2005, 7, 'Women')
        ax.tick_params(labelbottom='on') # added labelbottom='on' for bottom plot

## Second column of line charts for Liberal Arts degrees.
for sp in range(1,16,3):
    cat_index = int((sp-1)/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[cat_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[cat_index]], c=cb_orange, label='Men', linewidth=3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[cat_index])
    ax.tick_params(bottom='off', top='off', left='off', right='off', labelbottom='off') # added labelbottom='off'
    
    if cat_index == 0:
        ax.text(2005, 18, 'Men')
        ax.text(2003, 78, 'Women')
    elif cat_index == 4:
        ax.tick_params(labelbottom='on') # added labelbottom='on' for bottom plot

## Third column of line charts for Other degrees.
for sp in range(2,20,3):
    cat_index = int((sp-2)/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[cat_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[cat_index]], c=cb_orange, label='Men', linewidth=3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[cat_index])
    ax.tick_params(bottom='off', top='off', left='off', right='off', labelbottom='off') # added labelbottom='off'
    
    if cat_index == 0:
        ax.text(2005, 5, 'Men')
        ax.text(2003, 90, 'Women')
    elif cat_index == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2003, 30, 'Women')
        ax.tick_params(labelbottom='on') # added labelbottom='on' for bottom plot

plt.show()

# %% [markdown]
# ## Setting y-axis Labels
#
# We want to remove the inner y-axis numbers to declutter the plots.

# %%
fig = plt.figure(figsize=(16,20))

## First column of line charts for STEM degrees.
for sp in range(0,18,3):
    cat_index = int(sp/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[cat_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[cat_index]], c=cb_orange, label='Men', linewidth=3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[cat_index])
    ax.tick_params(bottom='off', top='off', left='off', right='off', labelbottom='off')
    ax.set_yticks([0,100]) # enabling only 0 and 100 as y-axis ticks
    
    if cat_index == 0:
        ax.text(2005, 10, 'Men')
        ax.text(2003, 85, 'Women')
    elif cat_index == 5:
        ax.text(2003, 87, 'Men')
        ax.text(2005, 7, 'Women')
        ax.tick_params(labelbottom='on')

## Second column of line charts for Liberal Arts degrees.
for sp in range(1,16,3):
    cat_index = int((sp-1)/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[cat_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[cat_index]], c=cb_orange, label='Men', linewidth=3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[cat_index])
    ax.tick_params(bottom='off', top='off', left='off', right='off', labelbottom='off')
    ax.set_yticks([0,100]) # enabling only 0 and 100 as y-axis ticks
    
    if cat_index == 0:
        ax.text(2005, 18, 'Men')
        ax.text(2003, 78, 'Women')
    elif cat_index == 4:
        ax.tick_params(labelbottom='on')

## Third column of line charts for Other degrees.
for sp in range(2,20,3):
    cat_index = int((sp-2)/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[cat_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[cat_index]], c=cb_orange, label='Men', linewidth=3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[cat_index])
    ax.tick_params(bottom='off', top='off', left='off', right='off', labelbottom='off')
    ax.set_yticks([0,100]) # enabling only 0 and 100 as y-axis ticks
    
    if cat_index == 0:
        ax.text(2005, 5, 'Men')
        ax.text(2003, 90, 'Women')
    elif cat_index == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2003, 30, 'Women')
        ax.tick_params(labelbottom='on')

plt.show()

# %% [markdown]
# ## Adding a Horizontal Line
#
# When we add a horizontal line it gives us a better understanding of the gender breakdown.

# %%
fig = plt.figure(figsize=(16,20))

## First column of line charts for STEM degrees.
for sp in range(0,18,3):
    cat_index = int(sp/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[cat_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[cat_index]], c=cb_orange, label='Men', linewidth=3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[cat_index])
    ax.tick_params(bottom='off', top='off', left='off', right='off', labelbottom='off')
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3) # adding horizontal gray transparent line
    
    if cat_index == 0:
        ax.text(2005, 10, 'Men')
        ax.text(2003, 85, 'Women')
    elif cat_index == 5:
        ax.text(2003, 87, 'Men')
        ax.text(2005, 7, 'Women')
        ax.tick_params(labelbottom='on')

## Second column of line charts for Liberal Arts degrees.
for sp in range(1,16,3):
    cat_index = int((sp-1)/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[cat_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[cat_index]], c=cb_orange, label='Men', linewidth=3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[cat_index])
    ax.tick_params(bottom='off', top='off', left='off', right='off', labelbottom='off')
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3) # adding horizontal gray transparent line
    
    if cat_index == 0:
        ax.text(2005, 18, 'Men')
        ax.text(2003, 78, 'Women')
    elif cat_index == 4:
        ax.tick_params(labelbottom='on')

## Third column of line charts for Other degrees.
for sp in range(2,20,3):
    cat_index = int((sp-2)/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[cat_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[cat_index]], c=cb_orange, label='Men', linewidth=3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[cat_index])
    ax.tick_params(bottom='off', top='off', left='off', right='off', labelbottom='off')
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3) # adding horizontal gray transparent line
    
    if cat_index == 0:
        ax.text(2005, 5, 'Men')
        ax.text(2003, 90, 'Women')
    elif cat_index == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2003, 30, 'Women')
        ax.tick_params(labelbottom='on')

plt.show()

# %% [markdown]
# ## Exporting to a File
#
# Here we export our plots so we can use them in Word documents, Powerpoint presentations, or emails.

# %%
fig = plt.figure(figsize=(16,20))

## First column of line charts for STEM degrees.
for sp in range(0,18,3):
    cat_index = int(sp/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[cat_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[cat_index]], c=cb_orange, label='Men', linewidth=3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[cat_index])
    ax.tick_params(bottom='off', top='off', left='off', right='off', labelbottom='off')
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    
    if cat_index == 0:
        ax.text(2005, 10, 'Men')
        ax.text(2003, 85, 'Women')
    elif cat_index == 5:
        ax.text(2003, 87, 'Men')
        ax.text(2005, 7, 'Women')
        ax.tick_params(labelbottom='on')

## Second column of line charts for Liberal Arts degrees.
for sp in range(1,16,3):
    cat_index = int((sp-1)/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[cat_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[cat_index]], c=cb_orange, label='Men', linewidth=3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[cat_index])
    ax.tick_params(bottom='off', top='off', left='off', right='off', labelbottom='off')
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    
    if cat_index == 0:
        ax.text(2005, 18, 'Men')
        ax.text(2003, 78, 'Women')
    elif cat_index == 4:
        ax.tick_params(labelbottom='on')

## Third column of line charts for Other degrees.
for sp in range(2,20,3):
    cat_index = int((sp-2)/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[cat_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[cat_index]], c=cb_orange, label='Men', linewidth=3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[cat_index])
    ax.tick_params(bottom='off', top='off', left='off', right='off', labelbottom='off')
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    
    if cat_index == 0:
        ax.text(2005, 5, 'Men')
        ax.text(2003, 90, 'Women')
    elif cat_index == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2003, 30, 'Women')
        ax.tick_params(labelbottom='on')

fig.savefig('gender_degrees.png') # exporting file before calling pyplot.show()       
plt.show()

# %% [markdown]
# ## Conclusion
#
# In this project we created visualizations that effectively and cleanly communicate gender gaps among various bachelor degrees received over several decades.
#
# The idea for this project comes from the [DATAQUEST](https://app.dataquest.io/) **Storytelling Through Data Visualization** course.
