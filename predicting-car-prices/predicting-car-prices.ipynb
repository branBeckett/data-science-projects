# %% [markdown]
# # Predicting Car Prices
#
#
#
#
#
# ## Exploring the Data

# %%
import pandas as pd
import numpy as np

pd.options.display.max_columns = 100

# %%
# There are no column headers in our dataset so we will add our own based off of dataset's documentation
column_names = ['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 
        'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 
        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-rate', 'horsepower',
        'peak-rpm', 'city-mpg', 'highway-mpg', 'price']

cars = pd.read_csv('imports-85.data', names=column_names)

# %%
cars.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %%
# Selecting only the numeric columns that can be used as features and selecting our target column for predictions
numeric_columns = ['normalized-losses', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-size',
                   'bore', 'stroke', 'compression-rate', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg',
                   'price']
numeric_cars = cars[numeric_columns]

# %% [markdown]
# ## Cleaning the Data

# %%
numeric_cars = numeric_cars.replace('?', np.nan)
numeric_cars.head()
# Out:
#   normalized-losses  wheel-base  length  width  height  curb-weight  \
# 0               NaN        88.6   168.8   64.1    48.8         2548
# 1               NaN        88.6   168.8   64.1    48.8         2548
# 2               NaN        94.5   171.2   65.5    52.4         2823
# 3               164        99.8   176.6   66.2    54.3         2337
# 4               164        99.4   176.6   66.4    54.3         2824
#
#    engine-size  bore stroke  compression-rate horsepower peak-rpm  city-mpg  \
# 0          130  3.47   2.68               9.0        111     5000        21
# 1          130  3.47   2.68               9.0        111     5000        21
# 2          152  2.68   3.47               9.0        154     5000        19
# 3          109  3.19   3.40              10.0        102     5500        24
# 4          136  3.19   3.40               8.0        115     5500        18
#
#    highway-mpg  price
# 0           27  13495
# 1           27  16500
# 2           26  16500
# ...

# %% [markdown]
# The '?' that we just converted to null values were originally cast to the pandas object as a string, so these columns need to be converten back into a numeric type.

# %%
numeric_cars = numeric_cars.astype('float')

# %%
numeric_cars.isnull().sum()
# Out:
# normalized-losses    41
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-size           0
# bore                  4
# stroke                4
# compression-rate      0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %% [markdown]
# We can't have any missing values in our dataset, and because `price` is going to be the column we are predicting, we will remove these rows.

# %%
numeric_cars = numeric_cars.dropna(subset=['price'])
numeric_cars.isnull().sum()
# Out:
# normalized-losses    37
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-size           0
# bore                  4
# stroke                4
# compression-rate      0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %% [markdown]
# We'll replace the missing values in the other columns with the column's mean value.

# %%
numeric_cars = numeric_cars.fillna(numeric_cars.mean())
numeric_cars.isnull().sum()
# Out:
# normalized-losses    0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-size          0
# bore                 0
# stroke               0
# compression-rate     0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %% [markdown]
# Our last step to cleaning the data before training our model is to normalize all of our columns except `price` so that their values fall between 0 and 1.

# %%
price_save = numeric_cars['price']
numeric_cars = (numeric_cars - numeric_cars.min()) / (numeric_cars.max() - numeric_cars.min())
numeric_cars['price'] = price_save

# %% [markdown]
# ## Univariate Model
