# %% [markdown]
# # Analyzing Wikipedia Pages
#
# In this project, we'll analyze 54 megabytes worth of data scraped from Wikipedia articles to find patterns in the writing and content style. We'll do this by implementing our own simplified version of something like the `grep` command-line utility. Our goals will be to make a case-insensitive search for all occurrences of a given string in all files and provide the specific locations of the files where that string is found.
#
# ## Introduction to the Wikipedia Data
#
# The articles were scraped by downloading the contents on random Wikipedia pages using the code found in `scrape_random.py` file, and then saved using the last component of their URLs into the `wiki` folder. Note: due to the large amount of data, I've added only a few of these files to this repository to serve as an example.
#
# The first thing will do is list all of the files in our `wiki` folder, and then open up some of the files to see what our data looks like.

# %%
import os

# Listing out the file names
file_names = os.listdir('wiki')
file_names
# Out:
# ['Ronald_McCaffer.html',
#  'IwakiIshikawa_Station.html',
#  'Communities_of_Tulu_Nadu.html',
#  'Meydane_Jahad_Metro_Station.html',
#  '2014E2809315_Kansas_State_Wildcats_men27s_basketball_team.html',
#  'Mountune_Racing.html',
#  'Tim_Spencer_(singer).html',
#  'Nathaniel_Merriman.html',
#  'Embraer_Unidade_GaviC3A3o_Peixoto_Airport.html',
#  'Campus_of_Texas_A26M_University.html',
#  'One_Night_of_Sin.html',
#  'Zgornji_Otok.html',
#  'Josef_Mik.html',
#  'Lin_Chiayu.html',
#  'Gaston_Lane.html',
#  '2008_Fed_Cup_World_Group_II.html',
#  'Phenacobius_catostomus.html',
#  'Hebden_Bridge_Picture_House.html',
#  'ThorntonleBeans.html',
#  'Lower_Blackburn_Grade_Bridge.html',
#  'HD_90156.html',
#  'Cyclohexane_conformation.html',
#  'Bifidocarpus.html',
#  'Terry_Cox.html',
#  'Kentucky_Theater.html',
#  'Alexander_Rizzoni.html',
#  'Charged_Records.html',
#  'Kate_Harwood.html',
#  'Aniavan.html',
#  'Doumanaba.html',
#  'East_Down_(Northern_Ireland_Parliament_constituency).html',
#  'Coenaculum_secundum.html',
#  'Switzerland_at_the_1992_Winter_Olympics.html',
#  'Dragnet_(franchise).html',
#  'List_of_Polish_consorts.html',
#  'Naoise_C393_MuirC3AD.html',
#  'James_Alexander_Ulio.html',
#  'Svendborg_SkibsvC3A6rft.html',
#  'ISMACryp.html',
#  '2009_World_Junior_Ice_Hockey_Championships_rosters.html',
#  'Ownership_of_Rangers_F.C..html',
#  'Theonellamide_F.html',
#  'Sir_Run_Run_Shaw_Hospital.html',
#  'Fischli.html',
#  'Woodward_Dream_Cruise.html',
#  'Dialogue_for_Hungary.html',
#  'Maple_Jam_Music_Group.html',
#  'Maukala.html',
#  'Brograve_Mill.html',
#  'Minister_of_Foreign_Affairs_(Egypt).html',
#  'Kirsten_Klein.html',
#  'Andrei_Gamalyan.html',
#  'Rubber_Biscuit.html',
#  'Boardman_Township_Mahoning_County_Ohio.html',
#  'USS_Impeccable_(AM320).html',
#  'Brownfield_(software_development).html',
#  'Frithjof_Schmidt.html',
#  'Udi_Enugu.html',
#  'Senapati_district.html',
#  'United_Nations_Security_Council_Resolution_731.html',
#  'Socket_423.html',
#  'Arthur_L._Aidala.html',
#  'Kistenuten.html',
#  'Santa_Maria_Imbaro.html',
#  'Kattukukke.html',
#  'Saladino27s_Inc.html',
#  'Gregory_Fortuin.html',
#  'Marv_Felderman.html',
#  'Bagrat_VI_of_Georgia.html',
#  'Friendship_Wake_County_North_Carolina.html',
#  'Supermoon.html',
#  'Elisa_von_der_Recke.html',
#  'The_Audacity_to_Podcast.html',
#  'Meneng_Constituency.html',
#  'Short_Message_service_center.html',
#  'WFGIFM.html',
#  'ThalkirchenObersendlingForstenriedFC3BCrstenriedSolln.html',
#  'Progressive_refinement.html',
#  'SBOA_School_26_Junior_College.html',
#  'Derek_Acorah.html',
#  'Jonas_ArC48Dikauskas.html',
#  'Hermann_Nuding.html',
#  'Glinka_(crater).html',
#  'John_Shaw_Rennie.html',
#  'Alpine_skiing_at_the_1994_Winter_Olympics_E28093_Men27s_combined.html',
#  'Lis_LC3B8wert.html',
#  'Burmese_shrike.html',
#  'Kettu_Kalyanam.html',
#  'Harry_Sacksioni.html',
#  'Clear_Creek_Township_Cooper_County_Missouri.html',
#  'KDDQ.html',
#  'Gacharageini.html',
#  'Football_Foundation.html',
#  'Mariana_Mazzucato.html',
#  'Martinus_Hamconius.html',
#  'KMTZ.html',
#  'Bazemore_Alabama.html',
#  'Hagen_Hauptbahnhof.html',
#  'Church_of_the_SubGenius.html',
#  'William_Harvey_Lillard.html',
#  'Battle_of_Wattignies.html',
#  'Checkerspot_(magazine).html',
#  'Paser_Crossword_Stela.html',
#  'Carthage_Cincinnati.html',
#  'Durham_Women27s_F.C..html',
#  'List_of_numberone_singles_of_1993_(Finland).html',
#  'Manhattan_Murder_Mystery.html',
#  'SolydXK.html',
#  'Arcadio_GonzC3A1lez.html',
#  'Teskey_Kyrgyzstan.html',
#  'Post_(structural).html',
#  'Shpolskii_matrix.html',
#  'Vrila.html',
#  'Mrs._Wilkes27_Dining_Room.html',
#  'John_Reid_(British_Army_officer).html',
#  'Moosavi_Peace_Formula.html',
#  'The_Future_(film).html',
#  'Sarah_BlakleyCartwright.html',
#  'Vitaly_Bianki.html',
#  'Troso_da_Monza.html',
#  'Archibald_Gordon_(British_Army_officer).html',
#  'Lake_County_Examiner.html',
#  'FC_Bobruisk.html',
#  'Virajpet_(Vidhan_Sabha_constituency).html',
#  'C11orf30.html',
#  'Evene.html',
#  'Bill_Widenhouse.html',
#  'Tomohiko_ItC58D_(director).html',
#  'Wolfgang_Lutz.html',
#  'Zane_Radcliffe.html',
#  'Abdulla_Majid_Al_Naimi.html',
#  'Neurotica.html',
#  'Manitoba_general_election_1896.html',
#  'Wangeroogeclass_tug.html',
#  'Bijou_California.html',
#  'Liebig_Peak.html',
#  'Lucius_Allen_(politician).html',
#  'Bulbonaricus.html',
#  'King_Parker_House.html',
#  'DWTETV.html',
#  'Jotedar.html',
#  'Vojin_C486etkoviC487.html',
#  'Mecklenburg_Switzerland_and_Lake_Kummerow_Nature_Park.html',
#  'Lord_Howe27s_action_or_the_Glorious_First_of_June.html',
#  'Henry_Horace_Williams.html',
#  'Tommy_Hunter_(baseball).html',
#  'Fahy_County_Mayo.html',
#  'Hexachaeta_colombiana.html',
#  'Weiser_River.html',
#  'Alan_Sheehan.html',
#  'Potheri_village_Kanchipuram.html',
#  'BBCHscale_(rice).html',
#  '2011_UK_Open_Qualifier_4.html',
#  'Timothy_Wanyonyi_Wetangula.html',
#  'Shanghai_Shuffle.html',
#  'CecylC3B3wkaBrzC3B3zka.html',
#  'Copamyntis_infusella.html',
#  'Eggerberg_railway_station.html',
#  'Watsonville_Junction_California.html',
#  'Saravan_Gilan.html',
#  'Isaac_GrC3BCnewald.html',
#  'Kolound.html',
#  'TapatC3ADo_hot_sauce.html',
#  'Wilhelm_Wagenfeld_House.html',
#  'Swathi_Chinukulu.html',
#  'Aylon_Darwin_Tavella.html',
#  'The_Land_of_the_Dead.html',
#  'MarC3ADa_CalderC3B3n.html',
#  'Canyamars.html',
#  'USS_Goldcrest.html',
#  'Australian_Musician_(magazine).html',
#  'Crabeating_frog.html',
#  'Johnny_B._Moore.html',
#  'AlMidan.html',
#  'Egg_coffee.html',
#  'Charles_Smith_Wilcox.html',
#  'Chhaparband_(Muslim).html',
#  'Norderbrarup.html',
#  'Aubrey_Fair.html',
#  'Helena_Nyblom.html',
#  'Fraser_Lake_Airport.html',
#  'The_Showdown_Effect.html',
#  'Dowell_Philip_O27Reilly.html',
#  'C27est_la_vie_(Khaled_song).html',
#  'Canbelego_County.html',
#  'Ctenodes_zonata.html',
#  'Battle_of_Isonzo_(489).html',
#  'David_Jesson.html',
#  'Majeepura.html',
#  'Chestnut_pie.html',
#  'Johann_Christoph_Hoffbauer.html',
#  'Hoghiz.html',
#  'Code_page_1023.html',
#  'JeecyVea.html',
#  'Simon27s_Town_railway_station.html',
#  '1915_Montana_football_team.html',
#  'Kelvin_Mbilinyi.html',
#  'Kiev_Missal.html',
#  'Central_Luzon.html',
#  'Phil_Spence.html',
#  'Vanavara_Airport.html',
#  '2004_Tuvalu_ADivision.html',
#  'Curtis_Whitley.html',
#  'Meleh_Kabude_Sofla.html',
#  'Flat_roof.html',
#  'Acceptance_(Heroes).html',
#  'Martha_Herbert.html',
#  'XCops_(band).html',
#  'Thomas_Croci.html',
#  'I_Am_Cold.html',
#  'Heiko_MC3A4rz.html',
#  'Millennium_Art_Academy.html',
#  'Victor_S._Mamatey.html',
#  'GbiriNiragu_language.html',
#  'La_Roca_de_la_Sierra.html',
#  'Walter_of_Durham.html',
#  'Antibiotic_use_in_livestock.html',
#  'Arabic_Toilers27_Movement.html',
#  'TamC3A1s_Buday.html',
#  'AB_v_CD.html',
#  'Giardini_Margherita.html',
#  'Achaea_faber.html',
#  'Pixley_Township_Clay_County_Illinois.html',
#  'MarieJosC3A8phe_Jude.html',
#  'UtielRequena.html',
#  'Prisons_in_Bolivia.html',
#  'List_of_gold_medalists_at_2006_South_Asian_Games.html',
#  'Punjab_War.html',
#  'Saratoga_Automobile_Museum.html',
#  'Cygany_Masovian_Voivodeship.html',
#  'Linowiec_KuyavianPomeranian_Voivodeship.html',
#  'Dextran_1.html',
#  'Pushkar.html',
#  'Avenira.html',
#  'Archiepiscopal_Palace_Rouen.html',
#  'Svinjare.html',
#  'Pictogram.html',
#  'Devarampally.html',
#  'Epropetes_metallica.html',
#  'Viva_Villa.html',
#  'C58CnogC58D_Station.html',
#  '2005E2809306_in_Welsh_football.html',
#  'Bias.html',
#  'Omar_Onsi.html',
#  'Now_That27s_What_I_Call_Music_55_(U.S._series).html',
#  'Flashmob_(album).html',
#  'Panchamrutham.html',
#  'Treaty_of_Warsaw_(1970).html',
#  'Shigeo_Kurata.html',
#  'Jack_Graham_(pastor).html',
#  'Apocephalus_borealis.html',
#  'Ribboned_sweetlips.html',
#  'Steinkjersannan.html',
#  'Symeon_Stylites_of_Lesbos.html',
#  'The_K_of_D.html',
#  'Elio_Calderini.html',
#  'Belvedere_London.html',
#  'Patrick_F._Philbin.html',
#  'Charlton_baronets.html',
#  'Cristian_Berdeja.html',
#  'A_Month_of_Sundays_(miniseries).html',
#  'Lungujja.html',
#  'Ma_Sen.html',
#  'Ordinary_singularity.html',
#  'GoodnightE28093Loving_Trail.html',
#  'Camp_Liberty_killings.html',
#  'I_Marine_Expeditionary_Force.html',
#  'Ballard_Memorial_High_School.html',
#  '2017_Orange_County_Breakers_season.html',
#  'Celebrity_doll.html',
#  'Sibling_Revelry.html',
#  'Odder.html',
#  'Ovum_Recordings.html',
#  'Oktyabrsky_District_Russia.html',
#  'Heinz_Inniger.html',
#  'Tongyi_Mingin.html',
#  'Keeled_sideband.html',
#  'Seminemacheilus.html',
#  'Typhoon_Hester_(1952).html',
#  'Sudanese_pound.html',
#  'Daniel_Cerone.html',
#  'Teiji_Ito.html',
#  'List_of_mountains_of_the_Falkland_Islands.html',
#  'Shellie_Morris.html',
#  'Nobuhiko_Ushiba.html',
#  'The_Purpose_Driven_Church.html',
#  '1951_National_League_tiebreaker_series.html',
#  'Abdelwahid_Aboud_Mackaye.html',
#  'Nyck_de_Vries.html',
#  'Ragnar_Gustavsson.html',
#  'Octomeria_lithophila.html',
#  'Faces_(RunE28093D.M.C._song).html',
#  'Devitt_Insurance.html',
#  'Kokan_Colony.html',
#  'Boogie_Bunnies.html',
#  'Eudonia_notozeucta.html',
#  'John_Nelson_(merchant).html',
#  'Endre_Church.html',
#  'Ricard_CardC3BAs.html',
#  'ARA_Garibaldi.html',
#  'Coup_d27C3A9tat.html',
#  'PTPRS.html',
#  'L._Fry.html',
#  'Baadj.html',
#  'Paul_Kenny_(politician).html',
#  'Pirama.html',
#  'Hayes_Township_Clay_County_Kansas.html',
#  'Louis_Vivet.html',
#  'Holly_Golightly_(comics).html',
#  '2013_FIA_WTCC_Race_of_Russia.html',
#  'Old_Mill_Creek_Illinois.html',
#  'CabriniE28093Green_Chicago.html',
#  'New_York_Women_Composers_Inc..html',
#  'Children_of_the_Grave.html',
#  'Robert_K._Zukowski.html',
#  'Urban_chicken.html',
#  'List_of_largest_chemical_producers.html',
#  '2016_Minnesota_Vikings_season.html',
#  'H._T._Hackney_Company.html',
#  'Ban_On.html',
#  'Hepatitis_B_virus.html',
#  'My_Life_(Billy_Joel_song).html',
#  '1896_Indiana_Hoosiers_football_team.html',
#  'Olivaceous_flatbill.html',
#  'Dysgonia_pudica.html',
#  'Constance_D27Arcy_Mackay.html',
#  'FC_Khikhani_Khulo.html',
#  'Koevtsi_Gabrovo_Province.html',
#  'Epichorista.html',
#  'Peltigera_membranacea.html',
#  'North_Otago_Astronomical_Society_Observatory.html',
#  'Jack_Wong.html',
#  'Gardenbased_learning.html',
#  'Morgana_King.html',
#  'Women27s_javelin_throw_world_record_progression.html',
#  'Bruce_Conte.html',
#  'Parkgate_railway_station.html',
#  'I27ve_Heard_That_Song_Before.html',
#  'Harry_Hill_Bandholtz.html',
#  'Radial_Road_3.html',
#  '985_Innovative_Platforms_for_Key_Disciplines_Project.html',
#  'When_You_Loved_Me.html',
#  'United_Nations_Security_Council_Resolution_1923.html',
#  'Imperial_Venus_(film).html',
#  'Macroglossum_pseudoluteata.html',
#  'Dewoitine_D.21.html',
#  'Feel_No_Fret.html',
#  'Pedro_Checa.html',
#  'Section_20_of_the_Canadian_Charter_of_Rights_and_Freedoms.html',
#  'William_Harper_(South_Carolina).html',
#  '2009_English_cricket_season.html',
#  'Zhongxing_Guesthouse.html',
#  'Kelvin_R._Throop.html',
#  'Carte_Imagine27R.html',
#  'John_Whewell.html',
#  'Appa_(film).html',
#  'Turkish_Men27s_Volleyball_Championship.html',
#  'Vang_stone.html',
#  'Mammoth_Unified_School_District.html',
#  'Syngenor.html',
#  'Dominique_Voynet.html',
#  'List_of_Bellator_MMA_events.html',
#  'Estelle_v._Smith.html',
#  'Oculorespiratory_syndrome.html',
#  'Goran_ObradoviC487_(footballer_born_1976).html',
#  'HMS_Robust.html',
#  'Furubira_District_Hokkaido.html',
#  'Leuke_Kome.html',
#  'Shabbir_Kumar.html',
#  '2007E2809308_Huddersfield_Town_A.F.C._season.html',
#  'Monarch_Mountain.html',
#  'Pichoy_Airfield.html',
#  'Oleg_Novitskiy.html',
#  'H._Larue_Renfroe.html',
#  'Bibiana_Beglau.html',
#  'Eternamente_Romanticos.html',
#  'Syncretocarpus.html',
#  'Scott_McPherson.html',
#  'Yarkant_County.html',
#  'Marion_Rockefeller_Weber.html',
#  'Sambhaji_Raje_Chhatrapati.html',
#  'List_of_Bratz_episodes.html',
#  'Mark_Maunder.html',
#  'Kim_Yonghwa.html',
#  'Javier_Bruses.html',
#  'High_Efficiency_Image_File_Format.html',
#  'WLSR.html',
#  'Kul_Gul.html',
#  'Touch_FM_(Coventry).html',
#  'Arnold_Freiherr_von_Biegeleben.html',
#  'FalmanCounty_Acres_Texas.html',
#  'Sparganothis_saracana.html',
#  'Luvvie_Darling.html',
#  'I_Q_(book_series).html',
#  'Ameenapuram.html',
#  'Jens_Pauli_Skaalum.html',
#  'David_Sands_(psychologist).html',
#  'Revolutionary_Vol._1.html',
#  'GalC3A1pagos_Guadalajara.html',
#  'Asparuh_Peak.html',
#  '1st_Strategic_Aerospace_Division.html',
#  'Don_Raye.html',
#  'Belgium_women27s_national_field_hockey_team.html',
#  'Gennady_Lesun.html',
#  'Biorock.html',
#  'Amborella.html',
#  'Therese_Maron.html',
#  'Garrett_Lucash.html',
#  'Mitrella_guerreiroi.html',
#  'Don_Parsons_(ice_hockey).html',
#  'Adish_Aggarwala.html',
#  '2011_ITU_Duathlon_World_Championships.html',
#  'Bibliography_of_Niue.html',
#  'Ashley_Wisconsin.html',
#  'Bill_Overstreet.html',
#  '1898_Colgate_football_team.html',
#  'Roselawn_Indiana.html',
#  'Newfoundland_general_election_1848.html',
#  'Ordinary_Virginia.html',
#  'Ready_or_Not_(Young_JV_album).html',
#  'Blick_nach_Rechts.html',
#  'Pustiu_River.html',
#  'Football_at_the_National_Games_of_China.html',
#  'Johnny_Morris_(American_football).html',
#  'Sabari.html',
#  'Danny_Gray.html',
#  'Ego_Dominus_Tuus.html',
#  'EDP_Sarichioi_Wind_Farm.html',
#  '2001_Australian_Individual_Speedway_Championship.html',
#  'Philaeus.html',
#  'Bahmanabade_Olya.html',
#  'Solanum_chilliasense.html',
#  'Master_of_Space_and_Time.html',
#  'Anthony_Marten.html',
#  'Paul_Maddrell.html',
#  'C389cole_des_Mines_de_Douai.html',
#  'DuC5A1anovo.html',
#  'Sverre_Solberg.html',
#  'Blue_Heelers_(season_8).html',
#  'Turowo_Pomeranian_Voivodeship.html',
#  'The_Summer_King.html',
#  'Robin_Brooke.html',
#  'Kate_Quarrie.html',
#  'Maniitsoq_structure.html',
#  'Harry_Lynde_Bradley.html',
#  'Streatfeild_family.html',
#  'Enrique_Morales.html',
#  'List_of_people_from_Bangor_Maine.html',
#  'Kenneth_van_Kempen.html',
#  'Union_United_Church.html',
#  'MoneyHunt.html',
#  'North_Coast_(RTA_Rapid_Transit_station).html',
#  'Sierra_Leone_Studies.html',
#  'LlwynCus.html',
#  'Kendalia_Texas.html',
#  'Moses_Hardy.html',
#  'Coalville_Town_railway_station.html',
#  'Kailas_Pal.html',
#  'Mohammad_Reza_Niknahal.html',
#  'Christopher_Speer.html',
#  'Scarlet_wrasse.html',
#  'Craig_Chester.html',
#  'ZNF644.html',
#  'Queensland_Music_Festival.html',
#  'TC58DrC58D_nagashi.html',
#  'Land_26_Water_Australia.html',
#  'Geomancer_(comics).html',
#  'Ioana_Badea.html',
#  'Lake_Lagunitas.html',
#  'Cheddar_Ales.html',
#  'Abbeville_Sluggers.html',
#  'St._Paul_University_Iloilo.html',
#  '2001_NCAA_Division_I_Field_Hockey_Championship.html',
#  'William_Henry_Porter.html',
#  'James_Wilkes_Maurice.html',
#  'List_of_lakes_in_Independence_County_Arkansas.html',
#  'SC3B8rli.html',
#  'Wilbraham_26_Monson_Academy.html',
#  'Joint_Social_Welfare_Institute.html',
#  'Larvicide.html',
#  'Gorgopis_subrimosa.html',
#  'John_Jephson.html',
#  'Danish_Maritime_Safety_Administration.html',
#  'Tischofer_Cave.html',
#  'Love_Sax_and_Flashbacks.html',
#  'Avengers_Academy.html',
#  'Jane_Wrightson.html',
#  'Companys_procC3A9s_a_Catalunya.html',
#  'Oued_TlC3A9lat.html',
#  'Metis_Institute_of_Polytechnic.html',
#  '2015E2809316_Washington_Huskies_men27s_basketball_team.html',
#  'Instrumental.html',
#  'Puerto_Rico_at_the_2013_World_Aquatics_Championships.html',
#  'I27m_Walking_Behind_You.html',
#  'Robert_Boehringer.html',
#  'Middle_Park_Victoria.html',
#  'The_Portal_(community_center).html',
#  'SotC481panna.html',
#  'DresdenPlauen_railway_station.html',
#  'Jules_Verne_ATV.html',
#  'Phong_ThE1BAA1nh_C490C3B4ng_A.html',
#  'Ingrid_GuimarC3A3es.html',
#  'Cannabis_in_Spain.html',
#  'Colchester_Village_Historic_District.html',
#  'Charles_Page_(cricketer).html',
#  'Minardi_M185.html',
#  'Clay_Township_Clark_County_Missouri.html',
#  'Le_Premier_Sexe.html',
#  'U.S._Snowboarding_Race_to_the_Cup.html',
#  'Henry_Louis_Larsen.html',
#  '1958_Wightman_Cup.html',
#  'Mount_Jim_Crow_National_Park.html',
#  'Frost_Township_Michigan.html',
#  'British_Academy_Television_Award_for_Best_Comedy_(Programme_or_Series).html',
#  'Laredo_Colombia_Solidarity_Port_of_Entry.html',
#  'Taylour_Paige.html',
#  'It27s_Just_My_Funny_Way_of_Laughin27.html',
#  '16th_Virginia_Infantry.html',
#  'Social_impact_of_YouTube.html',
#  'Zehut.html',
#  'Caney_Creek_(Matagorda_Bay).html',
#  'Clive_Brown_(footballer).html',
#  'Oldham_Metropolitan_Borough_Council_election_2000.html',
#  'Omaha_Racers.html',
#  'Eugamandus_brunneus.html',
#  'James_L._Hull.html',
#  'SSR180711.html',
#  'Robert_E._Lee_(FCC).html',
#  'Antigonadotropin.html',
#  'National_Register_of_Historic_Places_listings_in_Allen_Parish_Louisiana.html',
#  'Lectionary_69.html',
#  'Smeaton_East_Lothian.html',
#  'Sweeper.html',
#  'Yasid.html',
#  'Nejat_Alp.html',
#  '1988_State_of_Origin_series.html',
#  'Yemeni_rial.html',
#  'C389taule.html',
#  'Henri_BraqueniC3A9.html',
#  'Medicago_murex.html',
#  'James_Magee.html',
#  'Kyokutou_I_Love_You.html',
#  'Anton_von_Troeltsch.html',
#  'List_of_women27s_football_clubs_in_Japan.html',
#  'Sky_Regional_Airlines.html',
#  'Challenger_Banque_Nationale_de_Drummondville.html',
#  'Schlettau.html',
#  'Failing_Office_Building.html',
#  'GewC3A4chshaus_fC3BCr_tropische_Nutzpflanzen.html',
#  '2016E2809317_Little_Rock_Trojans_women27s_basketball_team.html',
#  'Jazz_in_Turkey.html',
#  'Liberty_Central_School_District.html',
#  'How_Can_We_Hang_On_to_a_Dream3F.html',
#  'Luca_Luciano.html',
#  '83_(number).html',
#  'Diplacus_aurantiacus.html',
#  'SumbaE28093Flores_languages.html',
#  'Uruguayan_constitutional_referendum_2014.html',
#  'Town_Yetholm.html',
#  'John_V._G._Posey_House.html',
#  'Claire_Danes.html',
#  'Blue_SWAT.html',
#  'Pedro_Machuca.html',
#  'Burnley_Borough_Council_election_2011.html',
#  'Priscus_of_Epirus.html',
#  'Rudy_The_Rudy_Giuliani_Story.html',
#  'Merwin_Hodel.html',
#  'Chapel_of_Mercy_MonacoVille.html',
#  'Cryptographic_primitive.html',
#  'Rally_for_Democracy_and_Progress_(Benin).html',
#  'Castle_of_Cardona.html',
#  'Sobolewo_Wysokie_Mazowieckie_County.html',
#  'Volume_One_(The_West_Coast_Pop_Art_Experimental_Band_album).html',
#  'Government_Polytechnic_Nagriya_Mod_Etah.html',
#  'Arkansas_Highway_178.html',
#  'Shoreyjehye_Do.html',
#  'Oliver_Twist_(1912_American_film).html',
#  'Guaricana_National_Park.html',
#  'Alan_Oakley.html',
#  'Ivo_Siromahov.html',
#  'Uralochka_Zlatoust.html',
#  'Wheatland_High_School_(California).html',
#  'Ayish_Bayou.html',
#  'Beyond_Magnetic.html',
#  'Vaccinium_padifolium.html',
#  'Jyoti_Raju.html',
#  'Ben_H._Williams.html',
#  'Yuga_(film).html',
#  'Shinpei_Matsushita.html',
#  'Kfarhata.html',
#  'Wu_Jin.html',
#  'Yoshinkan.html',
#  'Kusaka_Station.html',
#  'Stephen_Unwin_(director).html',
#  '100_Greatest_Romanians.html',
#  'Mick_Kelly_(Australian_footballer).html',
#  'Burbridge_Creek.html',
#  'Pontefract_byelection_1941.html',
#  'Reb_Russell.html',
#  'Curridge.html',
#  'Double_Wing_Attack.html',
#  '1953E2809354_FA_Cup_qualifying_rounds.html',
#  'Redwater_Mississippi.html',
#  'Programa_Mejorando_tu_Autoestima.html',
#  'Palio_zosterae.html',
#  'Clocking_Out_Is_for_Suckers.html',
#  'Sagrai.html',
#  'Arthur_Norman.html',
#  'Tubular_Bells_II.html',
#  'Emmanuel_Muhammad.html',
#  'Alexios_Aspietes.html',
#  'Keshav_Ginde.html',
#  'Roman_Catholic_Diocese_of_Cervia.html',
#  'RF_microwave_CAE_CAD.html',
#  'Julien_Boisselier.html',
#  'Tillandsia_intermedia.html',
#  'Awali.html',
#  'Hideki_Kase.html',
#  'The_Master_Plan_(album).html',
#  'Qatar_at_the_2013_World_Championships_in_Athletics.html',
#  'Early_medieval_states_in_Kazakhstan.html',
#  'Meir_Zlotowitz.html',
#  'PrC3A9liminaires.html',
#  'City_of_Mandaluyong_Science_High_School.html',
#  'CurtissWright_Hangar_(Columbia_South_Carolina).html',
#  'Bob_Bass.html',
#  'Mark_Baker_(basketball).html',
#  '2010_Karshi_Challenger_E28093_Singles.html',
#  'Brendan_Foster.html',
#  'YC3AAn_BC3A1i.html',
#  'Santa_MarC3ADa_YavesC3ADa.html',
#  'List_of_Nymphaeales_of_Montana.html',
#  'Agnolin.html',
#  'Eugenio_Morelli.html',
#  'Intel_QuickPath_Interconnect.html',
#  'Hall_of_Mental_Cultivation.html',
#  'Mykines_Greece.html',
#  'Olive_Dennis.html',
#  'Ksar_Nalut.html',
#  'Wilhelm_August_Graah.html',
#  'Sanford_Wallace.html',
#  'Adolf_Schulte.html',
#  'Clinton_Engineer_Works.html',
#  'BernardAugustin_Conroy.html',
#  'Italian_submarine_Comandante_FaC3A0_di_Bruno.html',
#  'Dean_Kukan.html',
#  'Cosmopterix_similis.html',
#  'Exploratorium_(film).html',
#  'Carlos_Martins_(musician).html',
#  'Table_Point_Formation.html',
#  'Russian_Cultural_Centre_(Lviv).html',
#  'Miltochrista_fuscozonata.html',
#  'Fusinus_carvalhoriosi.html',
#  'Wilson_Global_Explorer.html',
#  'Alex_Kurtzman.html',
#  'Luiz_Henrique_Santos.html',
#  'Somarasampettai.html',
#  'Berzeliustinden.html',
#  'WintersWimberley_House.html',
#  'Jeff_Weise.html',
#  'Unionidae.html',
#  'Stade_Municipal_de_Djougou.html',
#  'Equestrian_at_the_1936_Summer_Olympics.html',
#  'Bonny_River.html',
#  'Margo_Reuten.html',
#  'Kendal_Williams.html',
#  'Plasnewydd.html',
#  'Irihirose_Station.html',
#  'Benny_Lee.html',
#  'List_of_Spaghetti_Western_films.html',
#  'David_Beasley.html',
#  'Venezuelan_referendum_1957.html',
#  '2016E2809317_New_Zealand_Football_Championship.html',
#  'Diphilus_(physician).html',
#  'Claudia_Neidig.html',
#  'Alex_McEachern.html',
#  'Roger_Brooke.html',
#  'Dennis_Chapman.html',
#  'ParaC3B1aque_National_High_School_Don_Galo_Annex.html',
#  'Clay_Research_Award.html',
#  'Baltic_Peak.html',
#  'Smilax_laurifolia.html',
#  'Qalat_Kat.html',
#  'Taipa_HousesE28093Museum.html',
#  'Bengt_Forsberg.html',
#  'Two_House_theology.html',
#  'Vijay_Govindarajan.html',
#  'Josh_West.html',
#  'Bill_Price_(baseball).html',
#  'Mirisah.html',
#  '1910_in_literature.html',
#  'Bye_My_Boy.html',
#  'Myrtle_(sternwheeler).html',
#  'Maneswar_Brahma.html',
#  'Dick_Johnson_(clarinetist).html',
#  'Papyrus_Oxyrhynchus_56.html',
#  'Redeyed_dove.html',
#  'The_Lavender_Cowboy.html',
#  'Circus_Avenue.html',
#  'SC3BCderelbe.html',
#  'Lydia_VillaKomaroff.html',
#  'Museum_of_John_Paul_II_Collection.html',
#  'Westchester_Los_Angeles.html',
#  'Upper_Beaches.html',
#  'Morten_RutkjC3A6r.html',
#  'Elgin_National_Watch_Company.html',
#  'Heo_Mok.html',
#  'Havnar_RC3B3C3B0rarfelag.html',
#  'Sybra_preapicemaculata.html',
#  'Sahanpur.html',
#  'Legge.html',
#  'Tarsila_do_Amaral.html',
#  'Suri_Kerman.html',
#  'Young_Finnish_Party.html',
#  'Klaus_Gerwien.html',
#  'Larry_Brooks.html',
#  'Hemet_Public_Library.html',
#  'FC3A9lix_CC3A1rdenas.html',
#  'PlzeC588_Zoo.html',
#  'Schwobsheim.html',
#  'Vancouver_Furious_George.html',
#  'Kamakshyanagar.html',
#  'Gemma_Doyle_(politician).html',
#  'Promises_Promises_(Incubus_song).html',
#  'Siuniu.html',
#  'Robert_Frederick_Blum.html',
#  'Gaetanus_Matthew_Perez.html',
#  'Mei_Lanfang.html',
#  'USS_Parris_Island_(AG72).html',
#  'Wren_Alabama.html',
#  'Ek_Dil_Sau_Afsane.html',
#  'George_Joseph_Trapp.html',
#  'ItalyE28093United_States_relations.html',
#  'Charles_Stuart_(rugby_union).html',
#  'Pochyta.html',
#  'Russian_Party_in_Estonia.html',
#  'Gottfried_Keller.html',
#  'Sol_Eclipse.html',
#  'A_Sport_and_a_Pastime.html',
#  'Emily_(1964_song).html',
#  'Marson.html',
#  'Ugo_Okoye.html',
#  'George_Ellicott.html',
#  'Zoom_Systems.html',
#  'Devil_on_Horseback.html',
#  'Hemiargyropsis_frontalis.html',
#  'USS_General_Putnam_(1857).html',
#  'AVM_GmbH.html',
#  'Lebanon_at_the_1980_Winter_Olympics.html',
#  'Horace_Pinker.html',
#  'Bowie_Race_Track.html',
#  'Macy_conferences.html',
#  'Gorfion.html',
#  'Vivian_Prokop.html',
#  'Justus_Ferdinand_Poggenburg_II.html',
#  'Newton_Stone.html',
#  'Gulliver_Mickey.html',
#  'VSX2.html',
#  'Taggen_Nunatak.html',
#  'Nabil_Baha.html',
#  'Kanakomyrtus.html',
#  'Arthur_Lelyveld.html',
#  'Ferdinand_Mainzer.html',
#  'Tom_Buffington.html',
#  'Heald_Green.html',
#  'Sa_Re_Ga_Ma_Pa_Challenge_USA_2008.html',
#  'John_Maitland_(Royal_Navy_officer).html',
#  'List_of_birds_of_Malta.html',
#  'Varsity_College.html',
#  'Omiodes_iridias.html',
#  'The_Gentleman_Without_a_Residence_(1915_film).html',
#  'MOUSE_DHI.html',
#  'Bad_Luck_(Social_Distortion_song).html',
#  'Aldona_Orman.html',
#  'Valentin_Yanin.html',
#  'Gandigwad.html',
#  'Third_Saturday_in_October.html',
#  'Siege_of_Valenciennes_(1793).html',
#  'Roque_PC3A9rez_Partido.html',
#  'Nickel(II)_hydroxide.html',
#  'Jordan_Steel.html',
#  'Waldoboro_(CDP)_Maine.html',
#  'Russell_Road_(Ontario).html',
#  'Peringiella_denticulata.html',
#  'Acrolophus_simulatus.html',
#  'The_Wedding_(Sparks_novel).html',
#  'Discretionary_trust.html',
#  'Bartrum_Glacier.html',
#  'Swan_neck_deformity.html',
#  'Plains_Kansas.html',
#  'Lincoln_Clarkes.html',
#  'Ramo_Stott.html',
#  'Platinum_fulminate.html',
#  'Arun_K._Pati.html',
#  'John_C._Freeman_Weather_Museum.html',
#  'Kadamaha.html',
#  'Matthew_Liptak.html',
#  'The_Right_Kinda_Lover.html',
#  'Mike_Purdy.html',
#  'George_Jones_(bishop).html',
#  'Kenneth_Thomas_(cricketer).html',
#  'Els_Dottermans.html',
#  'G.O.Y.A._(Gunz_Or_Yay_Available).html',
#  'Carley_State_Park.html',
#  'Indhiya_Jananayaga_Katchi.html',
#  'Jazz_at_the_Plaza_Vol._II.html',
#  'Antipater_of_Thessalonica.html',
#  'SC_Goldau.html',
#  'Erigeron_canaani.html',
#  'Thanks_Again.html',
#  'Roll27s_partridge.html',
#  'The_Wire_(JTFGTMO).html',
#  '2011_Wainwright_Roaming_Buffalo_Classic.html',
#  'Giants27_grave_of_S27Ena27e_Thomes.html',
#  'Luciano_Mercante.html',
#  'Raymond_II_Count_of_Toulouse.html',
#  'Antonio_de_Zayas_(bishop).html',
#  'Caprinia_versicolor.html',
#  'Mudramothiram.html',
#  'Functoid.html',
#  'Crepidula_atrasolea.html',
#  'The_LoveGirl_and_the_Innocent.html',
#  'Cortile_del_Belvedere.html',
#  'Bay_of_ConcepciC3B3n.html',
#  'Madhuri_Desai.html',
#  'West_Valley_Washington.html',
#  'Ministry_of_Development_Planning_and_Statistics.html',
#  '2014E2809315_Albanian_Third_Division.html',
#  'Rob_Jones_(footballer_born_1971).html',
#  'Mohamed_ElSayed.html',
#  'Sol_Orwell.html',
#  'Gordon_Bau.html',
#  'Lopez_v._Davis.html',
#  'Agaritine_gammaglutamyltransferase.html',
#  'Pergamus.html',
#  'Elzear_Torreggiani.html',
#  'Benidorm_Bastards.html',
#  'Keegan_Pereira_(footballer).html',
#  '55th_parallel_south.html',
#  'Oldfield_Baby_Great_Lakes.html',
#  'Copenhagen_Skatepark.html',
#  'Jonathan_A._Goldstein.html',
#  'Axel_Revold.html',
#  'William_McDonald_(Australian_politician).html',
#  'GaC5A1parci.html',
#  'List_of_molecular_graphics_systems.html',
#  'List_of_Argentine_Primera_DivisiC3B3n_transfers_January_2011.html',
#  'KUMT.html',
#  'Ron_Harvey_(rugby_union).html',
#  'SalemAuburn_Streets_Historic_District.html',
#  'Scrobipalpa_halophila.html',
#  'Miss_Guatemala_2008.html',
#  'Regina_Pacis_Catholic_Secondary_School.html',
#  'USS_Rose_Mary_(SP1216).html',
#  'Arrondissements_of_the_Yvelines_department.html',
#  'Aleksandra_JagieC582o.html',
#  'AlNurayn_Mosque.html',
#  'Chemin_d27Aylmer.html',
#  'Henrique_da_Silveira.html',
#  'Sentences_(composition).html',
#  'Taylor_Williamson.html',
#  'Second_Valley_South_Australia.html',
#  'HMS_Stratagem_(P234).html',
#  'Bluesin27_Around.html',
#  'Acacia_dermatophylla.html',
#  'Social_dualism.html',
#  'Filip_Pyrochta.html',
#  'Shibanov.html',
#  '33rd_New_Jersey_Volunteer_Infantry.html',
#  'SC3A3o_SebastiC3A3o_do_Alto.html',
#  'Fortuna_Glacier.html',
#  'Markus_Blutsch.html',
#  'Baddiewinkle.html',
#  'Gratitud.html',
#  'MobiasBanca.html',
#  'Joint_Committee_for_Traceability_in_Laboratory_Medicine.html',
#  'Furto_di_sera_bel_colpo_si_spera.html',
#  'Australian_hardcore.html',
#  'Triptolemus_Evrychou.html',
#  'Ramana_Pakistan.html',
#  'Central_District_(Rezvanshahr_County).html',
#  'Antae_temple.html',
#  '2011E2809312_Western_Collegiate_Hockey_Association_women27s_ice_hockey_season.html',
#  'Urs_Burkart.html',
#  'William_de_Pembroke.html',
#  'List_of_Uzbek_films_of_2014.html',
#  'Sylvia_Moss.html',
#  'Kenny_Cordray.html',
#  'Wreck_Island_Natural_Area_Preserve.html',
#  'Hypocysta_angustata.html',
#  'Kreslyuvtsi.html',
#  'Eressa_aperiens.html',
#  'Eyes_Galaxies.html',
#  'Fureai_kippu.html',
#  'PoznaC584_Wola_railway_station.html',
#  'Lecithocera_sextacta.html',
#  'Chhatrasal.html',
#  'A_Beautiful_Valley.html',
#  'Golabkhvaran.html',
#  'Christine_Gardner.html',
#  'JaromC3ADr_C5A0imr.html',
#  'Konstantin_22Samokovetsa22_Dimitrov.html',
#  'Columbia_Airport_(Ohio).html',
#  'Suwannee_River_Junior_College.html',
#  'Hannover_Indians.html',
#  'Cobble_Hill_Brooklyn.html',
#  'Melanolagus_bericoides.html',
#  'Liga_de_FC3BAtbol_Profesional_Boliviano.html',
#  'Tropical_sprue.html',
#  'Foulonia.html',
#  'Jon_Mullich.html',
#  'Precorrin6A_reductase.html',
#  'Treaty_of_Ryswick.html',
#  'Neville_Hewitt_(American_football).html',
#  'Demographics_of_American_Samoa.html',
#  'Dakar_2_The_World27s_Ultimate_Rally.html',
#  'Nepal_at_the_2008_Summer_Paralympics.html',
#  'West_Park_Bridge.html',
#  'Power_transfer_unit.html',
#  'The_Hackensaw_Boys.html',
#  'La_Franja.html',
#  'Chef_Wan.html',
#  'Estadio_Municipal_Pozoblanco.html',
#  'Oligocentris_deciusalis.html',
#  'Seeking_Gaddafi.html',
#  'Hope_7_(album).html',
#  'Kristiene_Gong.html',
#  'Medical_Unit_Selfcontained_Transportable.html',
#  'Tonga_national_basketball_team.html',
#  'Kings_XI_Punjab_in_2014.html',
#  'Barren_vegetation.html',
#  'Jeff_Boyd.html',
#  'Lee_Henderson_Watkins.html',
#  'Bulbophyllum_biflorum.html',
#  'Banovina_of_Croatia.html',
#  'Jack_Goes_Home.html',
#  'Abanycha_bicolor.html',
#  'Dalian_Road_Station.html',
#  'Kellie_Jones.html',
#  'Mr_Freedom_(fashion).html',
#  'Imperial_amazon.html',
#  'DiGiorgio_Corporation.html',
#  'Kentucky_Auditor_election_2011.html',
#  'Strawberry_foliar_nematode.html',
#  'Charles_Sears.html',
#  'Zeiraphera.html',
#  'Greg_HalseyBrandt.html',
#  'Athletics_at_the_1994_Commonwealth_Games_E28093_Men27s_pole_vault.html',
#  'Hayateumi_Hidehito.html',
#  'Coronium_(gastropod).html',
#  'De_La_Salle_University_E28093_DasmariC3B1as.html',
#  'Mara_Keisling.html',
#  'Igor_and_Grichka_Bogdanoff.html',
#  'Arvind_Gokhale.html',
#  'Morning_Glory_(2010_film).html',
#  'Juan_Carlos_PinzC3B3n.html',
#  'Rules_of_Engagement_(Alexander_novel).html',
#  'William_Samuel_Viner.html',
#  'Aiva.html',
#  'Burnin27_Sneakers.html',
#  'Tomislav_Erceg.html',
#  'Urodilatin.html',
#  'Mick_Crotty.html',
#  'Poor_Richard27s_Almanack_(TV_series).html',
#  'Usher_Gahagan.html',
#  'Hilyard_Robinson.html',
#  'Meanings_of_minor_planet_names_440001E28093450000.html',
#  'Yarumal.html',
#  'Enamul_Haque_(cricketer_born_1966).html',
#  'PanhandleE28093Plains_Historical_Museum.html',
#  'Camp_Nelson_Confederate_Cemetery.html',
#  'Doug_Sahm_and_Band.html',
#  'Torovirinae.html',
#  'Corporation_(university).html',
#  'Tramery.html',
#  'Work_domain_analysis.html',
#  'Chief_Justice_of_New_Zealand.html',
#  'Cyclone_Gamede.html',
#  'S27portable_Scoreboards.html',
#  'BalC3A1zs_VillC3A1m.html',
#  'David_Solomona.html',
#  'PC582azC3B3wka.html',
#  'Desmiphora_bijuba.html',
#  'Nuno_Leal_Maia.html',
#  'Roxbury_Presbyterian_Church.html',
#  'Percy_William_Bunting.html',
#  'George_Weldrick.html',
#  'Peter_Collingwood.html',
#  'Abraham_Stanyan.html',
#  'Slade_School_of_Fine_Art.html',
#  'Van_Buren_Ohio.html',
#  'Tobi_trousers.html',
#  '104th_Logistic_Support_Brigade_(United_Kingdom).html',
#  'Noise_(song).html',
#  'Piracy_on_Falcon_Lake.html',
#  'Guyana_at_the_2010_Central_American_and_Caribbean_Games.html',
#  'St._Peter27s_Church_Tiberias.html',
#  'Webb_Dock_railway_line.html',
#  'List_of_Carboniferous_tetrapods.html']

# %%
len(file_names)
# Out:
# 999

# %%
# Read in and print the first file
with open(os.path.join('wiki', file_names[0])) as f:
    print(f.read())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Ronald McCaffer - Wikipedia</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# <script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Ronald_McCaffer","wgTitle":"Ronald McCaffer","wgCurRevisionId":726527002,"wgRevisionId":726527002,"wgArticleId":17402798,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["BLP articles lacking sources from March 2011","All BLP articles lacking sources","Articles with topics of unclear notability from March 2015","All articles with topics of unclear notability","All stub articles","Academics of Loughborough University","Scottish civil engineers","Fellows of the Royal Academy of Engineering","People associated with Cranfield University","1943 births","Living people","British academic biography stubs"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"Ronald_McCaffer","wgRelevantArticleId":17402798,"wgRequestId":"WLmm@wpAAEYAAgRBNtYAAACA","wgIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{}},"wgStableRevisionId":null,"wgWikiEditorEnabledModules":{"toolbar":true,"dialogs":true,"preview":false,"publish":false},"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsShouldSendModuleToUser":false,"wgPopupsConflictsWithNavPopupGadget":false,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","usePageImages":true,"usePageDescriptions":true},"wgPreferredVariant":"en","wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":true},"wgRelatedArticles":null,"wgRelatedArticlesBetaFeatureEnabled":false,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralNoticeCookiesToDelete":[],"wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgCategoryTreePageCategoryOptions":"{\"mode\":0,\"hideprefix\":20,\"showcount\":true,\"namespaces\":false}","wgWikibaseItemId":"Q7365100","wgCentralAuthMobileDomain":false,"wgVisualEditorToolbarScrollOffset":0,"wgEditSubmitButtonLabelPublish":false});mw.loader.state({"ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","user":"ready","user.options":"loading","user.tokens":"loading","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","mediawiki.sectionAnchor":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready"});mw.loader.implement("user.options@0j3lz3q",function($,jQuery,require,module){mw.user.options.set({"variant":"en"});});mw.loader.implement("user.tokens@1dqfd7l",function ( $, jQuery, require, module ) {
# mw.user.tokens.set({"editToken":"+\\","patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});/*@nomin*/;
#
# });mw.loader.load(["mediawiki.toc","mediawiki.action.view.postEdit","site","mediawiki.page.startup","mediawiki.user","mediawiki.hidpi","mediawiki.page.ready","mediawiki.legacy.wikibits","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.gadget.featured-articles-links","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging.subscriber","ext.wikimediaEvents","ext.navigationTiming","ext.uls.eventlogger","ext.uls.init","ext.uls.interface","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"]);});</script>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=ext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.sectionAnchor%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>
# <script async="" src="/w/load.php?debug=false&amp;lang=en&amp;modules=startup&amp;only=scripts&amp;skin=vector"></script>
# <meta name="ResourceLoaderDynamicStyles" content=""/>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>
# <meta name="generator" content="MediaWiki 1.29.0-wmf.14"/>
# <meta name="referrer" content="origin-when-cross-origin"/>
# <link rel="alternate" href="android-app://org.wikipedia/http/en.m.wikipedia.org/wiki/Ronald_McCaffer"/>
# <link rel="alternate" type="application/x-wiki" title="Edit this page" href="/w/index.php?title=Ronald_McCaffer&amp;action=edit"/>
# <link rel="edit" title="Edit this page" href="/w/index.php?title=Ronald_McCaffer&amp;action=edit"/>
# <link rel="apple-touch-icon" href="/static/apple-touch/wikipedia.png"/>
# <link rel="shortcut icon" href="/static/favicon/wikipedia.ico"/>
# <link rel="search" type="application/opensearchdescription+xml" href="/w/opensearch_desc.php" title="Wikipedia (en)"/>
# <link rel="EditURI" type="application/rsd+xml" href="//en.wikipedia.org/w/api.php?action=rsd"/>
# <link rel="copyright" href="//creativecommons.org/licenses/by-sa/3.0/"/>
# <link rel="canonical" href="https://en.wikipedia.org/wiki/Ronald_McCaffer"/>
# <link rel="dns-prefetch" href="//login.wikimedia.org"/>
# <link rel="dns-prefetch" href="//meta.wikimedia.org" />
# </head>
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject page-Ronald_McCaffer rootpage-Ronald_McCaffer skin-vector action-view">		<div id="mw-page-base" class="noprint"></div>
# 		<div id="mw-head-base" class="noprint"></div>
# 		<div id="content" class="mw-body" role="main">
# 			<a id="top"></a>
#
# 							<div id="siteNotice"><!-- CentralNotice --></div>
# 						<div class="mw-indicators">
# </div>
# 			<h1 id="firstHeading" class="firstHeading" lang="en">Ronald McCaffer</h1>
# 									<div id="bodyContent" class="mw-body-content">
# 									<div id="siteSub">From Wikipedia, the free encyclopedia</div>
# 								<div id="contentSub"></div>
# 												<div id="jump-to-nav" class="mw-jump">
# 					Jump to:					<a href="#mw-head">navigation</a>, 					<a href="#p-search">search</a>
# 				</div>
# 				<div id="mw-content-text" lang="en" dir="ltr" class="mw-content-ltr"><table class="plainlinks metadata ambox ambox-content ambox-multiple_issues compact-ambox" role="presentation">
# <tr>
# <td class="mbox-image">
# <div style="width:52px"><img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Ambox_important.svg/40px-Ambox_important.svg.png" width="40" height="40" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Ambox_important.svg/60px-Ambox_important.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Ambox_important.svg/80px-Ambox_important.svg.png 2x" data-file-width="40" data-file-height="40" /></div>
# </td>
# <td class="mbox-text">
# <div class="mw-collapsible" style="width:95%; margin: 0.2em 0;"><span class="mbox-text-span"><b>This article has multiple issues.</b> Please help <b><a class="external text" href="//en.wikipedia.org/w/index.php?title=Ronald_McCaffer&amp;action=edit">improve it</a></b> or discuss these issues on the <b><a href="/wiki/Talk:Ronald_McCaffer" title="Talk:Ronald McCaffer">talk page</a></b>. <small><i>(<a href="/wiki/Help:Maintenance_template_removal" title="Help:Maintenance template removal">Learn how and when to remove these template messages</a>)</i></small></span>
# <div class="mw-collapsible-content" style="margin-top: 0.3em;">
# <table class="plainlinks metadata ambox ambox-content ambox-BLP_sources" role="presentation">
# <tr>
# <td class="mbox-image">
# <div style="width:52px"><img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Ambox_important.svg/40px-Ambox_important.svg.png" width="40" height="40" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Ambox_important.svg/60px-Ambox_important.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Ambox_important.svg/80px-Ambox_important.svg.png 2x" data-file-width="40" data-file-height="40" /></div>
# </td>
# <td class="mbox-text"><span class="mbox-text-span">This <a href="/wiki/Wikipedia:Biographies_of_living_persons" title="Wikipedia:Biographies of living persons">biography of a living person</a> <b>needs additional <a href="/wiki/Wikipedia:Citing_sources" title="Wikipedia:Citing sources">citations</a> for <a href="/wiki/Wikipedia:Verifiability" title="Wikipedia:Verifiability">verification</a></b>. <span class="hide-when-compact">Please help by adding <a href="/wiki/Wikipedia:Identifying_reliable_sources" title="Wikipedia:Identifying reliable sources">reliable sources</a>. Contentious material about living persons that is unsourced or poorly sourced <b>must be removed immediately</b>, especially if potentially <a href="/wiki/Wikipedia:Libel" title="Wikipedia:Libel">libelous</a> or harmful.</span> <small><i>(March 2011)</i></small> <small class="hide-when-compact"><i>(<a href="/wiki/Help:Maintenance_template_removal" title="Help:Maintenance template removal">Learn how and when to remove this template message</a>)</i></small></span></td>
# </tr>
# </table>
# <table class="plainlinks metadata ambox ambox-content ambox-Notability" role="presentation">
# <tr>
# <td class="mbox-image">
# <div style="width:52px"><img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Ambox_important.svg/40px-Ambox_important.svg.png" width="40" height="40" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Ambox_important.svg/60px-Ambox_important.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Ambox_important.svg/80px-Ambox_important.svg.png 2x" data-file-width="40" data-file-height="40" /></div>
# </td>
# <td class="mbox-text"><span class="mbox-text-span">The topic of this article <b>may not meet Wikipedia's <a href="/wiki/Wikipedia:Notability_(academics)" title="Wikipedia:Notability (academics)">notability guideline for academics</a></b>. <span class="hide-when-compact">Please help to establish notability by citing <a href="/wiki/Wikipedia:Identifying_reliable_sources" title="Wikipedia:Identifying reliable sources">reliable secondary sources</a> that are <a href="/wiki/Wikipedia:Independent_sources" class="mw-redirect" title="Wikipedia:Independent sources">independent</a> of the topic and provide significant coverage of it beyond its mere trivial mention. If notability cannot be established, the article is likely to be <a href="/wiki/Wikipedia:Merging" title="Wikipedia:Merging">merged</a>, <a href="/wiki/Wikipedia:Redirect" title="Wikipedia:Redirect">redirected</a>, or <a href="/wiki/Wikipedia:Deletion_policy" title="Wikipedia:Deletion policy">deleted</a>.<br />
# <small><span class="plainlinks"><i>Find sources:</i>&#160;<a rel="nofollow" class="external text" href="//www.google.com/search?as_eq=wikipedia&amp;q=%22Ronald+McCaffer%22&amp;num=50">"Ronald McCaffer"</a>&#160;–&#160;<a rel="nofollow" class="external text" href="//www.google.com/search?q=%22Ronald+McCaffer%22&amp;tbm=nws">news</a>&#160;<b>·</b> <a rel="nofollow" class="external text" href="//www.google.com/search?&amp;q=%22Ronald+McCaffer%22+site:news.google.com/newspapers&amp;source=newspapers">newspapers</a>&#160;<b>·</b> <a rel="nofollow" class="external text" href="//www.google.com/search?tbs=bks:1&amp;q=%22Ronald+McCaffer%22">books</a>&#160;<b>·</b> <a rel="nofollow" class="external text" href="//scholar.google.com/scholar?q=%22Ronald+McCaffer%22">scholar</a>&#160;<b>·</b> <a rel="nofollow" class="external text" href="http://www.jstor.org/action/doBasicSearch?Query=%22Ronald+McCaffer%22&amp;acc=on&amp;wc=on">JSTOR</a>&#160;<b>·</b> <a rel="nofollow" class="external text" href="//www.google.com/images?safe=off&amp;tbm=isch&amp;tbs=sur:fmc&amp;q=%22Ronald+McCaffer%22+-site:wikipedia.org+-site:wikimedia.org">free images</a></span></small></span> <small><i>(March 2015)</i></small> <small class="hide-when-compact"><i>(<a href="/wiki/Help:Maintenance_template_removal" title="Help:Maintenance template removal">Learn how and when to remove this template message</a>)</i></small></span></td>
# </tr>
# </table>
# </div>
# </div>
# <small class="hide-when-compact"><i>(<a href="/wiki/Help:Maintenance_template_removal" title="Help:Maintenance template removal">Learn how and when to remove this template message</a>)</i></small></td>
# </tr>
# </table>
# <p><b>Ronald McCaffer</b> (born 1943) is Emeritus Professor of <a href="/wiki/Construction_Management" class="mw-redirect" title="Construction Management">Construction Management</a> at <a href="/wiki/Loughborough_University" title="Loughborough University">Loughborough University</a> in <a href="/wiki/Loughborough" title="Loughborough">Loughborough</a>, <a href="/wiki/England" title="England">England</a>. He is a specialist in the management of the processes, technology, contractual and procurement systems of the construction industry.</p>
# <p></p>
# <div id="toc" class="toc">
# <div id="toctitle">
# <h2>Contents</h2>
# </div>
# <ul>
# <li class="toclevel-1 tocsection-1"><a href="#Biography"><span class="tocnumber">1</span> <span class="toctext">Biography</span></a>
# <ul>
# <li class="toclevel-2 tocsection-2"><a href="#Early_life_and_education"><span class="tocnumber">1.1</span> <span class="toctext">Early life and education</span></a></li>
# <li class="toclevel-2 tocsection-3"><a href="#Academics_career"><span class="tocnumber">1.2</span> <span class="toctext">Academics career</span></a></li>
# <li class="toclevel-2 tocsection-4"><a href="#Honours"><span class="tocnumber">1.3</span> <span class="toctext">Honours</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-5"><a href="#Books"><span class="tocnumber">2</span> <span class="toctext">Books</span></a></li>
# <li class="toclevel-1 tocsection-6"><a href="#External_links"><span class="tocnumber">3</span> <span class="toctext">External links</span></a></li>
# </ul>
# </div>
# <p></p>
# <h2><span class="mw-headline" id="Biography">Biography</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Ronald_McCaffer&amp;action=edit&amp;section=1" title="Edit section: Biography">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <h3><span class="mw-headline" id="Early_life_and_education">Early life and education</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Ronald_McCaffer&amp;action=edit&amp;section=2" title="Edit section: Early life and education">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>McCaffer was born in <a href="/wiki/Glasgow" title="Glasgow">Glasgow</a>, <a href="/wiki/Scotland" title="Scotland">Scotland</a>. He received a BSc in Civil Engineering from <a href="/wiki/Strathclyde_University" class="mw-redirect" title="Strathclyde University">Strathclyde University</a> in 1965. He was awarded PhD in 1977 from Loughborough University and DSc in 1998 from University of Strathclyde.</p>
# <h3><span class="mw-headline" id="Academics_career">Academics career</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Ronald_McCaffer&amp;action=edit&amp;section=3" title="Edit section: Academics career">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>At Loughborough University, McCaffer has been Head of Civil Engineering (1987–1993), Dean of <a href="/wiki/Engineering" title="Engineering">Engineering</a> (1992–1997), Deputy Vice-Chancellor (1997–2002), Director of Strategic Business Partnerships, Innovation and Knowledge Transfer (2002–2006), and Emeritus Professor (since 2009).</p>
# <p>Other appointments have included duties at the <a href="/wiki/University_of_Technology,_Malaysia" title="University of Technology, Malaysia">University of Technology, Malaysia</a>, <a href="/wiki/University_of_Hong_Kong" title="University of Hong Kong">University of Hong Kong</a>, <a href="/wiki/University_of_New_South_Wales" title="University of New South Wales">University of New South Wales</a> and visiting Professor at <a href="/wiki/Glasgow_Caledonian_University" title="Glasgow Caledonian University">Glasgow Caledonian University</a>.</p>
# <h3><span class="mw-headline" id="Honours">Honours</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Ronald_McCaffer&amp;action=edit&amp;section=4" title="Edit section: Honours">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>McCaffer is a Fellow of the Royal Academy of Engineering (1991), Fellow of the Royal Society of Edinburgh (2009), Fellow of the <a href="/wiki/Royal_Academy_of_Engineering" title="Royal Academy of Engineering">Royal Academy of Engineering</a>, Fellow of the <a href="/wiki/Institution_of_Civil_Engineers" title="Institution of Civil Engineers">Institution of Civil Engineers</a> and Fellow of the <a href="/wiki/Chartered_Institute_of_Building" title="Chartered Institute of Building">Chartered Institute of Building</a>.</p>
# <p>He is a member of the Board of Trustees of the <a href="/wiki/British_University_in_Egypt" title="British University in Egypt">British University in Egypt</a>, and previously a member of Innovation East Midlands, a member of the Engineering Construction Industry Training Board and member of Court at <a href="/wiki/Cranfield_University" title="Cranfield University">Cranfield University</a>.</p>
# <h2><span class="mw-headline" id="Books">Books</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Ronald_McCaffer&amp;action=edit&amp;section=5" title="Edit section: Books">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <ul>
# <li><i>Modern Construction Management</i></li>
# <li><i>Management of Off Highway Plant and Equipment</i></li>
# <li><i>Worked Examples in Construction Management</i></li>
# </ul>
# <h2><span class="mw-headline" id="External_links">External links</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Ronald_McCaffer&amp;action=edit&amp;section=6" title="Edit section: External links">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <ul>
# <li><a rel="nofollow" class="external text" href="http://www.mccaffer.com">Home page</a> *<a rel="nofollow" class="external text" href="https://www.MERITgame.com">MERIT the international construction business game</a> *<a rel="nofollow" class="external text" href="http://eu.wiley.com/WileyCDA/WileyTitle/productCd-047067217X.html">Modern Construction Management</a></li>
# </ul>
# <p><br /></p>
# <table class="metadata plainlinks stub" role="presentation" style="background:transparent">
# <tr>
# <td><a href="/wiki/File:Flag_of_the_United_Kingdom.svg" class="image"><img alt="Stub icon" src="//upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/40px-Flag_of_the_United_Kingdom.svg.png" width="40" height="20" srcset="//upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/60px-Flag_of_the_United_Kingdom.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/80px-Flag_of_the_United_Kingdom.svg.png 2x" data-file-width="1200" data-file-height="600" /></a></td>
# <td><i>This biography article of a United Kingdom academic is a <a href="/wiki/Wikipedia:Stub" title="Wikipedia:Stub">stub</a>. You can help Wikipedia by <a class="external text" href="//en.wikipedia.org/w/index.php?title=Ronald_McCaffer&amp;action=edit">expanding it</a>.</i>
# <div class="plainlinks hlist navbar mini" style="position: absolute; right: 15px; display: none;">
# <ul>
# <li class="nv-view"><a href="/wiki/Template:UK-academic-bio-stub" title="Template:UK-academic-bio-stub"><abbr title="View this template">v</abbr></a></li>
# <li class="nv-talk"><a href="/wiki/Template_talk:UK-academic-bio-stub" title="Template talk:UK-academic-bio-stub"><abbr title="Discuss this template">t</abbr></a></li>
# <li class="nv-edit"><a class="external text" href="//en.wikipedia.org/w/index.php?title=Template:UK-academic-bio-stub&amp;action=edit"><abbr title="Edit this template">e</abbr></a></li>
# </ul>
# </div>
# </td>
# </tr>
# </table>
#
#
# <!--
# NewPP limit report
# Parsed by mw1179
# Cached time: 20170226213013
# Cache expiry: 2592000
# Dynamic content: false
# CPU time usage: 0.068 seconds
# Real time usage: 0.124 seconds
# Preprocessor visited node count: 302/1000000
# Preprocessor generated node count: 0/1500000
# Post‐expand include size: 34466/2097152 bytes
# Template argument size: 9121/2097152 bytes
# Highest expansion depth: 12/40
# Expensive parser function count: 2/500
# Lua time usage: 0.038/10.000 seconds
# Lua memory usage: 1.84 MB/50 MB
# -->
# <!--
# Transclusion expansion time report (%,ms,calls,template)
# 124.50%  118.004      3 Template:Ambox
# 100.00%   94.785      1 -total
#  87.78%   83.203      1 Template:Multiple_issues
#  30.21%   28.633      1 Template:Notability
#  23.63%   22.396      1 Template:Find_sources_mainspace
#  23.12%   21.915      1 Template:BLP_sources
#  12.04%   11.411      1 Template:UK-academic-bio-stub
#  10.60%   10.051      1 Template:Asbox
#   1.77%    1.676      2 Template:Main_other
# -->
#
# <!-- Saved in parser cache with key enwiki:pcache:idhash:17402798-0!*!0!!en!4!* and timestamp 20170226213013 and revision id 726527002
#  -->
# <noscript><img src="//en.wikipedia.org/wiki/Special:CentralAutoLogin/start?type=1x1" alt="" title="" width="1" height="1" style="border: none; position: absolute;" /></noscript></div>					<div class="printfooter">
# 						Retrieved from "<a dir="ltr" href="https://en.wikipedia.org/w/index.php?title=Ronald_McCaffer&amp;oldid=726527002">https://en.wikipedia.org/w/index.php?title=Ronald_McCaffer&amp;oldid=726527002</a>"					</div>
# 				<div id="catlinks" class="catlinks" data-mw="interface"><div id="mw-normal-catlinks" class="mw-normal-catlinks"><a href="/wiki/Help:Category" title="Help:Category">Categories</a>: <ul><li><a href="/wiki/Category:Academics_of_Loughborough_University" title="Category:Academics of Loughborough University">Academics of Loughborough University</a></li><li><a href="/wiki/Category:Scottish_civil_engineers" title="Category:Scottish civil engineers">Scottish civil engineers</a></li><li><a href="/wiki/Category:Fellows_of_the_Royal_Academy_of_Engineering" title="Category:Fellows of the Royal Academy of Engineering">Fellows of the Royal Academy of Engineering</a></li><li><a href="/wiki/Category:People_associated_with_Cranfield_University" title="Category:People associated with Cranfield University">People associated with Cranfield University</a></li><li><a href="/wiki/Category:1943_births" title="Category:1943 births">1943 births</a></li><li><a href="/wiki/Category:Living_people" title="Category:Living people">Living people</a></li><li><a href="/wiki/Category:British_academic_biography_stubs" title="Category:British academic biography stubs">British academic biography stubs</a></li></ul></div><div id="mw-hidden-catlinks" class="mw-hidden-catlinks mw-hidden-cats-hidden">Hidden categories: <ul><li><a href="/wiki/Category:BLP_articles_lacking_sources_from_March_2011" title="Category:BLP articles lacking sources from March 2011">BLP articles lacking sources from March 2011</a></li><li><a href="/wiki/Category:All_BLP_articles_lacking_sources" title="Category:All BLP articles lacking sources">All BLP articles lacking sources</a></li><li><a href="/wiki/Category:Articles_with_topics_of_unclear_notability_from_March_2015" title="Category:Articles with topics of unclear notability from March 2015">Articles with topics of unclear notability from March 2015</a></li><li><a href="/wiki/Category:All_articles_with_topics_of_unclear_notability" title="Category:All articles with topics of unclear notability">All articles with topics of unclear notability</a></li><li><a href="/wiki/Category:All_stub_articles" title="Category:All stub articles">All stub articles</a></li></ul></div></div>				<div class="visualClear"></div>
# 							</div>
# 		</div>
# 		<div id="mw-navigation">
# 			<h2>Navigation menu</h2>
#
# 			<div id="mw-head">
# 									<div id="p-personal" role="navigation" class="" aria-labelledby="p-personal-label">
# 						<h3 id="p-personal-label">Personal tools</h3>
# 						<ul>
# 							<li id="pt-anonuserpage">Not logged in</li><li id="pt-anontalk"><a href="/wiki/Special:MyTalk" title="Discussion about edits from this IP address [n]" accesskey="n">Talk</a></li><li id="pt-anoncontribs"><a href="/wiki/Special:MyContributions" title="A list of edits made from this IP address [y]" accesskey="y">Contributions</a></li><li id="pt-createaccount"><a href="/w/index.php?title=Special:CreateAccount&amp;returnto=Ronald+McCaffer" title="You are encouraged to create an account and log in; however, it is not mandatory">Create account</a></li><li id="pt-login"><a href="/w/index.php?title=Special:UserLogin&amp;returnto=Ronald+McCaffer" title="You're encouraged to log in; however, it's not mandatory. [o]" accesskey="o">Log in</a></li>						</ul>
# 					</div>
# 									<div id="left-navigation">
# 										<div id="p-namespaces" role="navigation" class="vectorTabs" aria-labelledby="p-namespaces-label">
# 						<h3 id="p-namespaces-label">Namespaces</h3>
# 						<ul>
# 															<li  id="ca-nstab-main" class="selected"><span><a href="/wiki/Ronald_McCaffer"  title="View the content page [c]" accesskey="c">Article</a></span></li>
# 															<li  id="ca-talk"><span><a href="/wiki/Talk:Ronald_McCaffer"  title="Discussion about the content page [t]" accesskey="t" rel="discussion">Talk</a></span></li>
# 													</ul>
# 					</div>
# 										<div id="p-variants" role="navigation" class="vectorMenu emptyPortlet" aria-labelledby="p-variants-label">
# 												<h3 id="p-variants-label">
# 							<span>Variants</span><a href="#"></a>
# 						</h3>
#
# 						<div class="menu">
# 							<ul>
# 															</ul>
# 						</div>
# 					</div>
# 									</div>
# 				<div id="right-navigation">
# 										<div id="p-views" role="navigation" class="vectorTabs" aria-labelledby="p-views-label">
# 						<h3 id="p-views-label">Views</h3>
# 						<ul>
# 															<li id="ca-view" class="selected"><span><a href="/wiki/Ronald_McCaffer" >Read</a></span></li>
# 															<li id="ca-edit"><span><a href="/w/index.php?title=Ronald_McCaffer&amp;action=edit"  title="Edit this page [e]" accesskey="e">Edit</a></span></li>
# 															<li id="ca-history" class="collapsible"><span><a href="/w/index.php?title=Ronald_McCaffer&amp;action=history"  title="Past revisions of this page [h]" accesskey="h">View history</a></span></li>
# 													</ul>
# 					</div>
# 										<div id="p-cactions" role="navigation" class="vectorMenu emptyPortlet" aria-labelledby="p-cactions-label">
# 						<h3 id="p-cactions-label"><span>More</span><a href="#"></a></h3>
#
# 						<div class="menu">
# 							<ul>
# 															</ul>
# 						</div>
# 					</div>
# 										<div id="p-search" role="search">
# 						<h3>
# 							<label for="searchInput">Search</label>
# 						</h3>
#
# 						<form action="/w/index.php" id="searchform">
# 							<div id="simpleSearch">
# 							<input type="search" name="search" placeholder="Search Wikipedia" title="Search Wikipedia [f]" accesskey="f" id="searchInput"/><input type="hidden" value="Special:Search" name="title"/><input type="submit" name="fulltext" value="Search" title="Search Wikipedia for this text" id="mw-searchButton" class="searchButton mw-fallbackSearchButton"/><input type="submit" name="go" value="Go" title="Go to a page with this exact name if it exists" id="searchButton" class="searchButton"/>							</div>
# 						</form>
# 					</div>
# 									</div>
# 			</div>
# 			<div id="mw-panel">
# 				<div id="p-logo" role="banner"><a class="mw-wiki-logo" href="/wiki/Main_Page"  title="Visit the main page"></a></div>
# 						<div class="portal" role="navigation" id='p-navigation' aria-labelledby='p-navigation-label'>
# 			<h3 id='p-navigation-label'>Navigation</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="n-mainpage-description"><a href="/wiki/Main_Page" title="Visit the main page [z]" accesskey="z">Main page</a></li><li id="n-contents"><a href="/wiki/Portal:Contents" title="Guides to browsing Wikipedia">Contents</a></li><li id="n-featuredcontent"><a href="/wiki/Portal:Featured_content" title="Featured content – the best of Wikipedia">Featured content</a></li><li id="n-currentevents"><a href="/wiki/Portal:Current_events" title="Find background information on current events">Current events</a></li><li id="n-randompage"><a href="/wiki/Special:Random" title="Load a random article [x]" accesskey="x">Random article</a></li><li id="n-sitesupport"><a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us">Donate to Wikipedia</a></li><li id="n-shoplink"><a href="//shop.wikimedia.org" title="Visit the Wikipedia store">Wikipedia store</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-interaction' aria-labelledby='p-interaction-label'>
# 			<h3 id='p-interaction-label'>Interaction</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="n-help"><a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia">Help</a></li><li id="n-aboutsite"><a href="/wiki/Wikipedia:About" title="Find out about Wikipedia">About Wikipedia</a></li><li id="n-portal"><a href="/wiki/Wikipedia:Community_portal" title="About the project, what you can do, where to find things">Community portal</a></li><li id="n-recentchanges"><a href="/wiki/Special:RecentChanges" title="A list of recent changes in the wiki [r]" accesskey="r">Recent changes</a></li><li id="n-contactpage"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia">Contact page</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-tb' aria-labelledby='p-tb-label'>
# 			<h3 id='p-tb-label'>Tools</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="t-whatlinkshere"><a href="/wiki/Special:WhatLinksHere/Ronald_McCaffer" title="List of all English Wikipedia pages containing links to this page [j]" accesskey="j">What links here</a></li><li id="t-recentchangeslinked"><a href="/wiki/Special:RecentChangesLinked/Ronald_McCaffer" rel="nofollow" title="Recent changes in pages linked from this page [k]" accesskey="k">Related changes</a></li><li id="t-upload"><a href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]" accesskey="u">Upload file</a></li><li id="t-specialpages"><a href="/wiki/Special:SpecialPages" title="A list of all special pages [q]" accesskey="q">Special pages</a></li><li id="t-permalink"><a href="/w/index.php?title=Ronald_McCaffer&amp;oldid=726527002" title="Permanent link to this revision of the page">Permanent link</a></li><li id="t-info"><a href="/w/index.php?title=Ronald_McCaffer&amp;action=info" title="More information about this page">Page information</a></li><li id="t-wikibase"><a href="https://www.wikidata.org/wiki/Q7365100" title="Link to connected data repository item [g]" accesskey="g">Wikidata item</a></li><li id="t-cite"><a href="/w/index.php?title=Special:CiteThisPage&amp;page=Ronald_McCaffer&amp;id=726527002" title="Information on how to cite this page">Cite this page</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-coll-print_export' aria-labelledby='p-coll-print_export-label'>
# 			<h3 id='p-coll-print_export-label'>Print/export</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="coll-create_a_book"><a href="/w/index.php?title=Special:Book&amp;bookcmd=book_creator&amp;referer=Ronald+McCaffer">Create a book</a></li><li id="coll-download-as-rdf2latex"><a href="/w/index.php?title=Special:Book&amp;bookcmd=render_article&amp;arttitle=Ronald+McCaffer&amp;returnto=Ronald+McCaffer&amp;oldid=726527002&amp;writer=rdf2latex">Download as PDF</a></li><li id="t-print"><a href="/w/index.php?title=Ronald_McCaffer&amp;printable=yes" title="Printable version of this page [p]" accesskey="p">Printable version</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-lang' aria-labelledby='p-lang-label'>
# 			<h3 id='p-lang-label'>Languages</h3>
#
# 			<div class="body">
# 									<ul>
# 											</ul>
# 				<div class='after-portlet after-portlet-lang'><span class="wb-langlinks-add wb-langlinks-link"><a href="https://www.wikidata.org/wiki/Q7365100#sitelinks-wikipedia" title="Add interlanguage links" class="wbc-editpage">Add links</a></span></div>			</div>
# 		</div>
# 				</div>
# 		</div>
# 		<div id="footer" role="contentinfo">
# 							<ul id="footer-info">
# 											<li id="footer-info-lastmod"> This page was last modified on 22 June 2016, at 19:12.</li>
# 											<li id="footer-info-copyright">Text is available under the <a rel="license" href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License">Creative Commons Attribution-ShareAlike License</a><a rel="license" href="//creativecommons.org/licenses/by-sa/3.0/" style="display:none;"></a>;
# additional terms may apply.  By using this site, you agree to the <a href="//wikimediafoundation.org/wiki/Terms_of_Use">Terms of Use</a> and <a href="//wikimediafoundation.org/wiki/Privacy_policy">Privacy Policy</a>. Wikipedia® is a registered trademark of the <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>
# 									</ul>
# 							<ul id="footer-places">
# 											<li id="footer-places-privacy"><a href="https://wikimediafoundation.org/wiki/Privacy_policy" class="extiw" title="wmf:Privacy policy">Privacy policy</a></li>
# 											<li id="footer-places-about"><a href="/wiki/Wikipedia:About" title="Wikipedia:About">About Wikipedia</a></li>
# 											<li id="footer-places-disclaimer"><a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">Disclaimers</a></li>
# 											<li id="footer-places-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>
# 											<li id="footer-places-developers"><a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">Developers</a></li>
# 											<li id="footer-places-cookiestatement"><a href="https://wikimediafoundation.org/wiki/Cookie_statement">Cookie statement</a></li>
# 											<li id="footer-places-mobileview"><a href="//en.m.wikipedia.org/w/index.php?title=Ronald_McCaffer&amp;mobileaction=toggle_view_mobile" class="noprint stopMobileRedirectToggle">Mobile view</a></li>
# 									</ul>
# 										<ul id="footer-icons" class="noprint">
# 											<li id="footer-copyrightico">
# 							<a href="https://wikimediafoundation.org/"><img src="/static/images/wikimedia-button.png" srcset="/static/images/wikimedia-button-1.5x.png 1.5x, /static/images/wikimedia-button-2x.png 2x" width="88" height="31" alt="Wikimedia Foundation"/></a>						</li>
# 											<li id="footer-poweredbyico">
# 							<a href="//www.mediawiki.org/"><img src="/static/images/poweredby_mediawiki_88x31.png" alt="Powered by MediaWiki" srcset="/static/images/poweredby_mediawiki_132x47.png 1.5x, /static/images/poweredby_mediawiki_176x62.png 2x" width="88" height="31"/></a>						</li>
# 									</ul>
# 						<div style="clear:both"></div>
# 		</div>
# 		<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.068","walltime":"0.124","ppvisitednodes":{"value":302,"limit":1000000},"ppgeneratednodes":{"value":0,"limit":1500000},"postexpandincludesize":{"value":34466,"limit":2097152},"templateargumentsize":{"value":9121,"limit":2097152},"expansiondepth":{"value":12,"limit":40},"expensivefunctioncount":{"value":2,"limit":500},"entityaccesscount":{"value":0,"limit":400},"timingprofile":["124.50%  118.004      3 Template:Ambox","100.00%   94.785      1 -total"," 87.78%   83.203      1 Template:Multiple_issues"," 30.21%   28.633      1 Template:Notability"," 23.63%   22.396      1 Template:Find_sources_mainspace"," 23.12%   21.915      1 Template:BLP_sources"," 12.04%   11.411      1 Template:UK-academic-bio-stub"," 10.60%   10.051      1 Template:Asbox","  1.77%    1.676      2 Template:Main_other"]},"scribunto":{"limitreport-timeusage":{"value":"0.038","limit":"10.000"},"limitreport-memusage":{"value":1926016,"limit":52428800}},"cachereport":{"origin":"mw1179","timestamp":"20170226213013","ttl":2592000,"transientcontent":false}}});});</script><script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":83,"wgHostname":"mw1275"});});</script>
# 	</body>
# </html>

# %% [markdown]
# ## Adding a MapReduce Framework
#
# We'll start by adding a MapReduce function to help us process the large amounts of data.

# %%
import math
import functools
from multiprocessing import Pool

def make_chunks(data, num_chunks):
    chunk_size = math.ceil(len(data) / num_chunks)
    return [data[i:i+chunk_size] for i in range(0, len(data), chunk_size)]

def map_reduce(data, num_processes, mapper, reducer):
    chunks = make_chunks(data, num_processes)
    pool = Pool(num_processes)
    chunk_results = pool.map(mapper, chunks)
    return functools.reduce(reducer, chunk_results)

# %% [markdown]
# ## Counting the Number of Lines in All Files

# %%
def map_line_count(file_names):
    total = 0
    for name in file_names:
        with open(os.path.join('wiki', name)) as f:
            total += len(f.readlines())
    return total

def reduce_line_count(count1, count2):
    return count1 + count2

map_reduce(file_names, 8, map_line_count, reduce_line_count)
# Out:
# 499797

# %% [markdown]
# # Grep

# %% [markdown]
# Select only a small amount of words from each article speeds up the algorithm. We could also choose to not include any words less that 5 characters in length as well to help us clean up some of the unnecessary values we see.
#
# ## Conclusion & Next Steps
#
# In this project we've done some basic analysis on scraped Wikipedia data and worked to optimize the code performance.
#
# Some next steps we could take to continue this analysis further could be to:
#
# * Look at what tags have the most content.
# * Find the articles that are most commonly linked.
# * Find the most common phrases.
# * Calculate the distribution of letters per word.
# * Use readability metrics to find the average reading level of Wikipedia articles.
# * Find what images are most commonly shown.
#
# We could continue to download as much data to work with as possible, and optimize our code to efficiently and effectively work with increasing amounts of data. The idea for this project comes from the [dataquest.io](https://app.dataquest.io/) **Parallel Processing** course.
